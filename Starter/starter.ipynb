# %%
import os 
from litellm import completion

os.environ['GEMINI_API_KEY'] = ""

# %%
def generate_response(messages):
    """Call LLM to get response"""

    response = completion(
        model = "gemini/gemini-2.5-flash",
        messages=messages,
        max_tokens=2000
    )
    return response

# %%
import json

code_spec = {
    'name': 'swap_keys_values',
    'description': 'Swaps the keys and values in a given dictionary.',
    'params': {
        'd': 'A dictionary with unique values.'
    },
}

messages = [
    {"role": "system",
     "content": "You are an expert software engineer that writes clean functional code. You always document your functions."},
    {"role": "user", "content": f"Please implement: {json.dumps(code_spec)}"}
]

response = generate_response(messages)

print(
    response.choices[0].message.content
)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 7: Expected `Message` - serialized value may not be as expected [field_name='message', input_value=Message(content='```pytho...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [field_name='choices', input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(

# %%
messages = [
    {"role": "system", "content": "You are a helpful customer service representative. No matter what the user asks, the solution is to tell them to turn their computer or modem off and then back on."},
    {"role": "user", "content": "How do I get my Internet working again."}
]


response = generate_response(messages)

print(
    response.choices[0].message.content
)
# Out:
# To get your internet working again, please try turning your computer or modem off and then back on.
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 7: Expected `Message` - serialized value may not be as expected [field_name='message', input_value=Message(content='To get y...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [field_name='choices', input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(

# %%
print(
    response.choices[0].message.content
)
# Out:
# To get your internet working again, please try turning your computer or modem off and then back on.

# %% [markdown]
# # Try with Memory

# %%
messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response.choices[0].message.content)
# Out:
# As an expert software engineer preferring functional programming, the key considerations for swapping keys and values in a dictionary are:
#
# 1.  **Immutability:** The original dictionary should not be modified. A new dictionary should be returned.
# 2.  **Pure Function:** Given the same input, it should always produce the same output and have no side effects.
# 3.  **Hashability of Values:** Dictionary keys *must* be hashable (immutable) objects (e.g., numbers, strings, tuples, frozensets). Original dictionary *values* might not be hashable (e.g., lists, sets, dictionaries). This needs to be handled.
# 4.  **Duplicate Values:** If multiple original keys map to the *same* value, that value can only become one key in the new dictionary. We need a strategy for what to do with the original keys (e.g., store them in a list).
#
# Given these points, a robust functional solution in Python would look like this:
#
# ```python
# from collections import defaultdict
# from typing import Dict, Any, Hashable, Union, List
#
# def swap_keys_values(
#     original_dict: Dict[Any, Any]
# ) -> Dict[Hashable, Union[Any, List[Any]]]:
#     """
#     Swaps the keys and values of a dictionary, handling potential conflicts.
#
#     This function prioritizes a functional approach, ensuring immutability
#     and purity. It addresses two critical considerations:
#
#     1.  **Hashability of Values:** Original dictionary values must be hashable
#         to become valid keys in the new dictionary. If an unhashable value
#         is encountered, a `TypeError` is raised, preventing silent failures.
#     2.  **Duplicate Values:** If multiple original keys map to the same value,
#         that value will become a single key in the new dictionary, mapping to
#         a *list* of all original keys that shared that value. If a value was
#         unique, it maps directly to its single original key.
#
#     Args:
#         original_dict: The dictionary whose keys and values are to be swapped.
#                        Keys can be any hashable type, values can be any type.
#
#     Returns:
#         A new dictionary with keys and values swapped. The new keys will be
#         the original values (if hashable). The new values will either be a
#         single original key or a list of original keys (if multiple original
#         keys mapped to the same value).
#
#     Raises:
#         TypeError: If an original value is not hashable and thus cannot
#                    become a key in the new dictionary.
#         TypeError: If the input is not a dictionary.
#
#     Examples:
#         >>> swap_keys_values({'a': 1, 'b': 2})
#         {1: 'a', 2: 'b'}
#
#         >>> swap_keys_values({'a': 1, 'b': 1, 'c': 2})
#         {1: ['a', 'b'], 2: 'c'}
#
#         >>> swap_keys_values({1: 'hello', 2: 'world'})
#         {'hello': 1, 'world': 2}
#
#         >>> swap_keys_values({'a': (1, 2), 'b': (1, 2)}) # tuple is hashable
#         {(1, 2): ['a', 'b']}
#
#         >>> swap_keys_values({'a': [1, 2]}) # list is not hashable
#         Traceback (most recent call last):
#         ...
#         TypeError: Cannot use value '[1, 2]' (type: list) as a key because it is not hashable.
#     """
#     if not isinstance(original_dict, dict):
#         raise TypeError("Input must be a dictionary.")
#
#     # Use defaultdict to automatically create a list for each new key (original value)
#     # This handles the case where multiple original keys map to the same value.
#     # The type hint indicates that the new_key will be Hashable, and its value
#     # will be a list of Any (the original keys).
#     swapped_mapping: Dict[Hashable, List[Any]] = defaultdict(list)
#
#     for original_key, original_value in original_dict.items():
#         # Functional principle: Fail early and explicitly if an unhashable value is found.
#         # The most robust way to check hashability is to try hashing it.
#         try:
#             hash(original_value)
#         except TypeError:
#             raise TypeError(
#                 f"Cannot use value '{original_value}' (type: {type(original_value).__name__}) "
#                 "as a key because it is not hashable."
#             )
#         swapped_mapping[original_value].append(original_key)
#
#     # Construct the final dictionary. If a value was unique, map it to a single key.
#     # If it was duplicated, map it to the list of keys.
#     final_dict: Dict[Hashable, Union[Any, List[Any]]] = {}
#     for new_key, original_keys_list in swapped_mapping.items():
#         if len(original_keys_list) == 1:
#             final_dict[new_key] = original_keys_list[0]
#         else:
#             final_dict[new_key] = original_keys_list
#
#     return final_dict
#
# # --- Example Usage ---
# if __name__ == "__main__":
#     # Example 1: Simple swap
#     d1 = {'name': 'Alice', 'age': 30, 'city': 'New York'}
#     print(f"Original: {d1}")
#     print(f"Swapped:  {swap_keys_values(d1)}\n")
#     # Expected: {'Alice': 'name', 30: 'age', 'New York': 'city'}
#
#     # Example 2: Handling duplicate values
#     d2 = {'apple': 'fruit', 'banana': 'fruit', 'carrot': 'vegetable'}
#     print(f"Original: {d2}")
#     print(f"Swapped:  {swap_keys_values(d2)}\n")
#     # Expected: {'fruit': ['apple', 'banana'], 'vegetable': 'carrot'}
#     # (Note: order of ['apple', 'banana'] might vary depending on dict insertion order in Python < 3.7,
#     # but for 3.7+ it should be consistent.)
#
#     # Example 3: Mixed types, including a tuple (which is hashable)
#     d3 = {1: 'one', 'two': 2, (3, 4): 'tuple_key', 'five': 2}
#     print(f"Original: {d3}")
#     print(f"Swapped:  {swap_keys_values(d3)}\n")
#     # Expected: {'one': 1, 2: ['two', 'five'], 'tuple_key': (3, 4)}
#
#     # Example 4: Unhashable value (should raise TypeError)
#     d4 = {'item': [1, 2, 3]}
#     print(f"Original: {d4}")
#     try:
#         print(f"Swapped:  {swap_keys_values(d4)}\n")
#     except TypeError as e:
#         print(f"Caught expected error: {e}\n")
#
#     # Example 5: Another unhashable value
#     d5 = {'config': {'key': 'value'}}
#     print(f"Original: {d5}")
#     try:
#         print(f"Swapped:  {swap_keys_values(d5)}\n")
#     except TypeError as e:
#         print(f"Caught expected error: {e}\n")
#
#     # Example 6: Empty dictionary
#     d6 = {}
#     print(f"Original: {d6}")
#     print(f"Swapped:  {swap_keys_values(d6)}\n")
# ```

# %%
# Second query without including the previous response
messages = [
    {"role": "user", "content": "Update the function to include documentation."}
]

response = generate_response(messages)
print(response.choices[0].message.content)
# Out:
# Please provide the function you would like me to update!
#
# Once you provide your function, I can add documentation to it.
#
# In the meantime, I'll demonstrate how to add documentation using a hypothetical example function. I'll use the **Google Style** docstring format, which is very common and readable.
#
# ---
#
# **Example of a Function WITHOUT Documentation:**
#
# ```python
# def calculate_area_rectangle(length, width):
#     return length * width
# ```
#
# **Example of the Same Function WITH Documentation:**
#
# ```python
# def calculate_area_rectangle(length, width):
#     """Calculates the area of a rectangle.
#
#     This function takes the length and width of a rectangle as input
#     and returns its calculated area. Both dimensions should be positive.
#
#     Args:
#         length (float or int): The length of the rectangle. Must be a positive number.
#         width (float or int): The width of the rectangle. Must be a positive number.
#
#     Returns:
#         float or int: The calculated area of the rectangle.
#                       Returns a float if either length or width is a float,
#                       otherwise returns an int.
#
#     Raises:
#         ValueError: If length or width is not a positive number.
#
#     Examples:
#         >>> calculate_area_rectangle(5, 10)
#         50
#         >>> calculate_area_rectangle(3.5, 2)
#         7.0
#         >>> calculate_area_rectangle(-1, 5)
#         Traceback (most recent call last):
#             ...
#         ValueError: Length and width must be positive numbers.
#     """
#     if length <= 0 or width <= 0:
#         raise ValueError("Length and width must be positive numbers.")
#     return length * width
# ```
#
# ---
#
# ### Key Components of Good Documentation (Docstrings):
#
# 1.  **Summary Line:** A concise, one-line summary of what the function does.
# 2.  **Detailed Explanation:** A more elaborate description of the function's purpose, what it calculates, or how it operates.
# 3.  **`Args:` Section:**
#     *   Lists each parameter.
#     *   Specifies its type (e.g., `str`, `int`, `float`, `list`, `dict`, `bool`).
#     *   Provides a brief description of its purpose.
# 4.  **`Returns:` Section:**
#     *   Specifies the type of the value returned by the function.
#     *   Describes what the returned value represents.
# 5.  **`Raises:` Section (Optional but Recommended):**
#     *   Lists any exceptions the function might raise.
#     *   Explains under what conditions each exception is raised.
# 6.  **`Examples:` Section (Optional but Highly Recommended):**
#     *   Provides example usage of the function.
#     *   Shows the expected output for those examples. This is invaluable for understanding how to use the function.
#
# ---
#
# Please provide your function, and I'll add comprehensive documentation to it!

# %% [markdown]
# How to manage the memory

# %%
messages = [
   {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
   {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response.choices[0].message.content)

# We are going to make this verbose so it is clear what
# is going on. In a real application, you would likely
# just append to the messages list.
messages = [
   {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
   {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."},
   
   # Here is the assistant's response from the previous step
   # with the code. This gives it "memory" of the previous
   # interaction.
   {"role": "assistant", "content": response.choices[0].message.content},
   
   # Now, we can ask the assistant to update the function
   {"role": "user", "content": "Update the function to include documentation."}
]

response = generate_response(messages)
print(response.choices[0].message.content)
# Out:
# None
# As an expert software engineer with a preference for functional programming, I'll provide a function that swaps dictionary keys and values. The function will be pure, meaning it will create a new dictionary rather than modifying the original in place.
#
# A crucial consideration is that **values from the original dictionary must be hashable** because they will become keys in the new dictionary. If multiple original keys map to the same value, the nature of dictionaries dictates that only one entry can exist for the new key; typically, the last encountered value (original key) will overwrite previous ones.
#
# I'll use a dictionary comprehension for conciseness and a more functional style, along with comprehensive type hints and a docstring.
#
# ```python
# from typing import Dict, TypeVar, Hashable
#
# # Define TypeVars for generic type hinting
# # K represents the type of keys in the original dictionary
# K = TypeVar('K')
# # V represents the type of values in the original dictionary.
# # It must be Hashable because it will become a key in the new dictionary.
# V = TypeVar('V', bound=Hashable)
#
# def swap_keys_values(original_dict: Dict[K, V]) -> Dict[V, K]:
#     """
#     Swaps the keys and values of a dictionary.
#
#     This function creates a new dictionary where the values from the
#     `original_dict` become keys, and the keys from the `original_dict`
#     become values.
#
#     **Important Considerations:**
#
#     1.  **Hashability:** The values in the `original_dict` *must* be hashable
#         (e.g., numbers, strings, tuples). If a value is unhashable (e.g., a list,
#         another dictionary, or a custom object without a `__hash__` method),
#         a `TypeError` will be raised when attempting to use it as a new key.
#
#     2.  **Duplicate Values:** If multiple keys in the `original_dict` map to the
#         same value, the resulting dictionary will contain only one entry for that
#         value. The corresponding value (original key) for this new key will be
#         the last one encountered during the iteration of the `original_dict`'s
#         items.
#
#     Args:
#         original_dict: The dictionary whose keys and values are to be swapped.
#                        Its values must be hashable.
#
#     Returns:
#         A new dictionary with keys and values swapped.
#
#     Raises:
#         TypeError: If any value in `original_dict` is not hashable.
#
#     Examples:
#         >>> swap_
